# %%
# environment: tensorflow 1.2

import tensorflow as tf
import numpy as np
import utils
import cells

# %%
########## Read data ##########

train_data_dir = "./data/TIMIT/phn/train/mfcc/"
train_label_dir = "./data/TIMIT/phn/train/label/"
test_data_dir = "./data/TIMIT/phn/test/mfcc/"
test_label_dir = "./data/TIMIT/phn/test/label/"

#each one is a list of 2D ([feature_num, time_step]) numpy data
train_data = utils.read_ndarray_from(train_data_dir) 
train_label = utils.read_ndarray_from(train_label_dir)
test_data = utils.read_ndarray_from(test_data_dir)
test_label = utils.read_ndarray_from(test_label_dir)

#---------for debugging model, we only test on a smaller dataset---------
train_data = train_data[0:100]
train_label = train_label[0:100]
test_data = test_data[0:100]
test_label = test_label[0:100] 
#------------------------------------------------------------------------


# Make a glance of data
print("{}'s {}, samples num: {}, each element has {}"\
      .format("train_data", type(train_data), len(train_data), type(train_data[0])))
print("{}'s {}, samples num: {}, each element has {}"\
      .format("train_label", type(train_label), len(train_label), type(train_label[0])))
print("{}'s {}, samples num: {}, each element has {}"\
      .format("test_data", type(test_data), len(test_data), type(test_data[0])))
print("{}'s {}, samples num: {}, each element has {}"\
      .format("test_label", type(test_label), len(test_label), type(test_label[0])))
# Out:
# train_data's <type 'list'>, samples num: 100, each element has <type 'numpy.ndarray'>
# train_label's <type 'list'>, samples num: 100, each element has <type 'numpy.ndarray'>
# test_data's <type 'list'>, samples num: 100, each element has <type 'numpy.ndarray'>
# test_label's <type 'list'>, samples num: 100, each element has <type 'numpy.ndarray'>

# %%
########## Define Hyper-parameters ##########
class Argument(object):
    def __init__(self):
        self.max_epoch = 500
        self.num_layers = 2
        self.num_hidden = 256
        self.num_classes = 62 
        self.batch_size = 32
        self.learning_rate = 0.001
        self.layer_norm = True
        self.dropout_prob = 0.1
        self.dropout_keep_prob = 1- self.dropout_prob
        
        self.num_feature = train_data[0].shape[0]
        self.max_timestep = utils.get_max_timestep(train_data, test_data)
        
        self.layer_norm = True
        self.cell_type = 'LSTMCell' #option: LSTMCell, RNNCell, GRUCell
#         self.activation = 'tanh' #option: tanh, ReLU

# %%
########## Define a model ##########

args = Argument()
graph = tf.Graph()
with graph.as_default():
    inputs = tf.placeholder(dtype=tf.float32, shape=[args.batch_size, args.max_timestep, args.num_feature], name="inputs")
    targetsIdx = tf.placeholder(tf.int64)
    targetsVal = tf.placeholder(tf.int32)
    targetsShape = tf.placeholder(tf.int64)
    targets = tf.SparseTensor(targetsIdx, targetsVal, targetsShape)
    seq_len = tf.placeholder(tf.int32, [args.batch_size], name="seq_len")
    
    #stack multi-layers cells
    stacked_cells = []
    for i in range(args.num_layers):
        cell = cells.select_cell(args)
        stacked_cells.append(cell)
    mul_cells = tf.contrib.rnn.MultiRNNCell(stacked_cells)
    
    #use dynamic rnn to get output lists and deprecated the last state
    #output shape: [batch_size, time_steps, num_hidden]
    output, _ = tf.nn.dynamic_rnn(mul_cells, inputs, seq_len, dtype=tf.float32)
    #define full connect layer
    logits = tf.layers.dense(output, args.num_classes)
    
    #time major, shape: [time_steps, batch_size, num_hidden]
    logits = tf.transpose(logits, [1, 0, 2])
    
    #optimizer 
    loss = tf.nn.ctc_loss(targets, logits, seq_len)
    cost = tf.reduce_mean(loss)
    
    optimizer = tf.train.AdamOptimizer(args.learning_rate).minimize(cost)
    
    
    
    predictions = tf.to_int32(
                tf.nn.ctc_beam_search_decoder(logits, seq_len, merge_repeated=False)[0][0])

# %%
######### 3. Start training     #########

batch_size = args.batch_size
max_epoch = args.max_epoch
num_samples = len(train_data)
level = 'phn'
# data_idx = np.random.permutation(num_samples)
(train_dataBatches, _) = utils.data_lists_to_batches(train_data, train_label, batch_size, level)
train_num_batches = len(train_dataBatches)
train_batchErrors = np.zeros(train_num_batches)

(test_dataBatches, _) = utils.data_lists_to_batches(test_data, test_label, batch_size, level)
test_num_batches = len(test_dataBatches)
test_batchErrors = np.zeros(test_num_batches)

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(max_epoch):
        for i in range(train_num_batches):
            batched_inputs, batched_sparse_targets, batched_seq_len = train_dataBatches[i]
            batched_targets_idx, batched_targets_val, batched_targets_shape = batched_sparse_targets
            feed_dict = {inputs:batched_inputs, targetsIdx:batched_targets_idx, targetsVal:batched_targets_val,\
                         targetsShape:batched_targets_shape, seq_len:batched_seq_len }
            _, cost_val, pre_y, y = sess.run([optimizer, cost, predictions, targets], feed_dict=feed_dict)
            
            er = utils.get_edit_distance([pre_y.values], [y.values], True, level)
            print('\n{} mode, total:{},batch:{}/{},epoch:{}/{},train loss=        for i in range(test_num_batches):
#             test_batched_inputs, test_batched_sparse_targets, test_batched_seq_len = test_dataBatches[i]
#             test_batched_targets_idx, test_batched_targets_val, test_batched_targets_shape = test_batched_sparse_targets
#             feed_dict = {inputs:test_batched_inputs, targetsIdx:test_batched_targets_idx, targetsVal:test_batched_targets_val,\
#                          targetsShape:test_batched_targets_shape,seq_len:test_batched_seq_len}
#             cost_val, pre_y, y = sess.run([cost, predictions, targets], feed_dict=feed_dict)
#             er = utils.get_edit_distance([pre_y.values], [y.values], True, level)
#             print('\n{} mode, batch:{}/{},epoch:{}/{},test loss={:.3f},mean test PER={:.3f}\n'.format(
#                 level , i+1, test_num_batches, epoch+1, max_epoch, cost_val, er))
#             test_batchErrors[i] = er * len(test_batched_seq_len)
            
{:.3f},mean train PER={:.3f}\n'.format(
                level, num_samples, i+1, train_num_batches, epoch+1, max_epoch, cost_val, er))
            train_batchErrors[i] = er * len(batched_seq_len)
            if i % 30 == 0:
                print('Truth:\n' + utils.output_to_sequence(y, type=level))
                print('Output:\n' + utils.output_to_sequence(pre_y, type=level))
        
#         for i in range(test_num_batches):
#             test_batched_inputs, test_batched_sparse_targets, test_batched_seq_len = test_dataBatches[i]
#             test_batched_targets_idx, test_batched_targets_val, test_batched_targets_shape = test_batched_sparse_targets
#             feed_dict = {inputs:test_batched_inputs, targetsIdx:test_batched_targets_idx, targetsVal:test_batched_targets_val,\
#                          targetsShape:test_batched_targets_shape,seq_len:test_batched_seq_len}
#             cost_val, pre_y, y = sess.run([cost, predictions, targets], feed_dict=feed_dict)
#             er = utils.get_edit_distance([pre_y.values], [y.values], True, level)
#             print('\n{} mode, batch:{}/{},epoch:{}/{},test loss={:.3f},mean test PER={:.3f}\n'.format(
#                 level , i+1, test_num_batches, epoch+1, max_epoch, cost_val, er))
#             test_batchErrors[i] = er * len(test_batched_seq_len)
# Out:
# phn mode, total:100,batch:1/3,epoch:1/500,train loss=1128.488,mean train PER=3.388
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# ux ix ax-h epi dx epi ax-h zh g n f ay nx aa nx aa nx eng w r bcl d eng eh eng eh th tcl th m th dcl axr tcl ax-h tcl ow tcl p ax-h p hv p uw hv t ah ow tcl uw tcl h# ux s ao s ao h# ao s er ch dcl ix t pau ix tcl ax-h tcl er tcl k tcl ax-h tcl axr nx axr eh l el l zh p dcl eh q f th er bcl er w s aw ih ay h# ay ax-h h# ax-h k ax-h k pau k ux k ch s ux ix r uh en zh m dx r dx eh dx eh hv q ix ch ix dx ix ao p zh p pau zh pau ao k hh k pcl k dx aa uw n dh d dh ix ax q jh sh jh sh dh ah ix ux ng ax th ay y ay y
#
# phn mode, total:100,batch:2/3,epoch:1/500,train loss=788.384,mean train PER=2.620
#
#
# phn mode, total:100,batch:3/3,epoch:1/500,train loss=368.575,mean train PER=0.793
#
#
# phn mode, total:100,batch:1/3,epoch:2/500,train loss=187.955,mean train PER=0.945
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# ix pcl
#
# phn mode, total:100,batch:2/3,epoch:2/500,train loss=141.927,mean train PER=0.951
#
#
# phn mode, total:100,batch:3/3,epoch:2/500,train loss=170.995,mean train PER=0.972
#
#
# phn mode, total:100,batch:1/3,epoch:3/500,train loss=173.820,mean train PER=0.981
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# ix
#
# phn mode, total:100,batch:2/3,epoch:3/500,train loss=141.281,mean train PER=0.975
#
#
# phn mode, total:100,batch:3/3,epoch:3/500,train loss=163.000,mean train PER=0.975
#
#
# phn mode, total:100,batch:1/3,epoch:4/500,train loss=160.099,mean train PER=0.971
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# dx
#
# phn mode, total:100,batch:2/3,epoch:4/500,train loss=129.701,mean train PER=0.964
#
#
# phn mode, total:100,batch:3/3,epoch:4/500,train loss=148.783,mean train PER=0.964
#
#
# phn mode, total:100,batch:1/3,epoch:5/500,train loss=149.530,mean train PER=0.941
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:5/500,train loss=125.479,mean train PER=0.879
#
#
# phn mode, total:100,batch:3/3,epoch:5/500,train loss=144.518,mean train PER=0.824
#
#
# phn mode, total:100,batch:1/3,epoch:6/500,train loss=147.690,mean train PER=0.802
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# dx dx dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:6/500,train loss=124.646,mean train PER=0.805
#
#
# phn mode, total:100,batch:3/3,epoch:6/500,train loss=141.881,mean train PER=0.793
#
#
# phn mode, total:100,batch:1/3,epoch:7/500,train loss=144.111,mean train PER=0.801
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# dx dx dx dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:7/500,train loss=120.731,mean train PER=0.801
#
#
# phn mode, total:100,batch:3/3,epoch:7/500,train loss=138.251,mean train PER=0.791
#
#
# phn mode, total:100,batch:1/3,epoch:8/500,train loss=140.623,mean train PER=0.800
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# dx dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:8/500,train loss=117.945,mean train PER=0.798
#
#
# phn mode, total:100,batch:3/3,epoch:8/500,train loss=136.806,mean train PER=0.817
#
#
# phn mode, total:100,batch:1/3,epoch:9/500,train loss=139.339,mean train PER=0.819
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:9/500,train loss=116.865,mean train PER=0.818
#
#
# phn mode, total:100,batch:3/3,epoch:9/500,train loss=136.083,mean train PER=0.837
#
#
# phn mode, total:100,batch:1/3,epoch:10/500,train loss=138.345,mean train PER=0.831
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:10/500,train loss=115.987,mean train PER=0.816
#
#
# phn mode, total:100,batch:3/3,epoch:10/500,train loss=134.862,mean train PER=0.827
#
#
# phn mode, total:100,batch:1/3,epoch:11/500,train loss=137.075,mean train PER=0.819
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:11/500,train loss=115.246,mean train PER=0.802
#
#
# phn mode, total:100,batch:3/3,epoch:11/500,train loss=133.703,mean train PER=0.813
#
#
# phn mode, total:100,batch:1/3,epoch:12/500,train loss=136.222,mean train PER=0.804
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:12/500,train loss=115.000,mean train PER=0.792
#
#
# phn mode, total:100,batch:3/3,epoch:12/500,train loss=133.103,mean train PER=0.796
#
#
# phn mode, total:100,batch:1/3,epoch:13/500,train loss=135.849,mean train PER=0.793
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:13/500,train loss=114.833,mean train PER=0.787
#
#
# phn mode, total:100,batch:3/3,epoch:13/500,train loss=132.683,mean train PER=0.793
#
#
# phn mode, total:100,batch:1/3,epoch:14/500,train loss=135.397,mean train PER=0.792
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:14/500,train loss=114.309,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:14/500,train loss=132.237,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:15/500,train loss=134.896,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:15/500,train loss=113.732,mean train PER=0.792
#
#
# phn mode, total:100,batch:3/3,epoch:15/500,train loss=131.992,mean train PER=0.806
#
#
# phn mode, total:100,batch:1/3,epoch:16/500,train loss=134.623,mean train PER=0.805
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:16/500,train loss=113.392,mean train PER=0.792
#
#
# phn mode, total:100,batch:3/3,epoch:16/500,train loss=131.884,mean train PER=0.810
#
#
# phn mode, total:100,batch:1/3,epoch:17/500,train loss=134.458,mean train PER=0.805
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:17/500,train loss=113.206,mean train PER=0.792
#
#
# phn mode, total:100,batch:3/3,epoch:17/500,train loss=131.693,mean train PER=0.806
#
#
# phn mode, total:100,batch:1/3,epoch:18/500,train loss=134.247,mean train PER=0.803
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:18/500,train loss=113.098,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:18/500,train loss=131.448,mean train PER=0.796
#
#
# phn mode, total:100,batch:1/3,epoch:19/500,train loss=134.053,mean train PER=0.793
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:19/500,train loss=113.067,mean train PER=0.787
#
#
# phn mode, total:100,batch:3/3,epoch:19/500,train loss=131.271,mean train PER=0.792
#
#
# phn mode, total:100,batch:1/3,epoch:20/500,train loss=133.913,mean train PER=0.791
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:20/500,train loss=113.024,mean train PER=0.787
#
#
# phn mode, total:100,batch:3/3,epoch:20/500,train loss=131.158,mean train PER=0.792
#
#
# phn mode, total:100,batch:1/3,epoch:21/500,train loss=133.773,mean train PER=0.792
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:21/500,train loss=112.896,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:21/500,train loss=131.086,mean train PER=0.795
#
#
# phn mode, total:100,batch:1/3,epoch:22/500,train loss=133.640,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:22/500,train loss=112.742,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:22/500,train loss=131.050,mean train PER=0.802
#
#
# phn mode, total:100,batch:1/3,epoch:23/500,train loss=133.543,mean train PER=0.803
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:23/500,train loss=112.627,mean train PER=0.792
#
#
# phn mode, total:100,batch:3/3,epoch:23/500,train loss=131.004,mean train PER=0.806
#
#
# phn mode, total:100,batch:1/3,epoch:24/500,train loss=133.457,mean train PER=0.804
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:24/500,train loss=112.554,mean train PER=0.792
#
#
# phn mode, total:100,batch:3/3,epoch:24/500,train loss=130.912,mean train PER=0.802
#
#
# phn mode, total:100,batch:1/3,epoch:25/500,train loss=133.370,mean train PER=0.801
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:25/500,train loss=112.510,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:25/500,train loss=130.804,mean train PER=0.796
#
#
# phn mode, total:100,batch:1/3,epoch:26/500,train loss=133.297,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:26/500,train loss=112.473,mean train PER=0.790
#
#
# phn mode, total:100,batch:3/3,epoch:26/500,train loss=130.713,mean train PER=0.795
#
#
# phn mode, total:100,batch:1/3,epoch:27/500,train loss=133.238,mean train PER=0.794
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:27/500,train loss=112.409,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:27/500,train loss=130.644,mean train PER=0.795
#
#
# phn mode, total:100,batch:1/3,epoch:28/500,train loss=133.181,mean train PER=0.795
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:28/500,train loss=112.320,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:28/500,train loss=130.591,mean train PER=0.796
#
#
# phn mode, total:100,batch:1/3,epoch:29/500,train loss=133.130,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:29/500,train loss=112.235,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:29/500,train loss=130.538,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:30/500,train loss=133.078,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:30/500,train loss=112.170,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:30/500,train loss=130.471,mean train PER=0.798
#
#
# phn mode, total:100,batch:1/3,epoch:31/500,train loss=133.022,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:31/500,train loss=112.122,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:31/500,train loss=130.394,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:32/500,train loss=132.963,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:32/500,train loss=112.078,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:32/500,train loss=130.324,mean train PER=0.796
#
#
# phn mode, total:100,batch:1/3,epoch:33/500,train loss=132.906,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:33/500,train loss=112.024,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:33/500,train loss=130.266,mean train PER=0.796
#
#
# phn mode, total:100,batch:1/3,epoch:34/500,train loss=132.848,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:34/500,train loss=111.960,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:34/500,train loss=130.213,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:35/500,train loss=132.792,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:35/500,train loss=111.897,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:35/500,train loss=130.157,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:36/500,train loss=132.736,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:36/500,train loss=111.843,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:36/500,train loss=130.093,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:37/500,train loss=132.679,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:37/500,train loss=111.796,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:37/500,train loss=130.023,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:38/500,train loss=132.623,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:38/500,train loss=111.748,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:38/500,train loss=129.955,mean train PER=0.796
#
#
# phn mode, total:100,batch:1/3,epoch:39/500,train loss=132.568,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:39/500,train loss=111.693,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:39/500,train loss=129.890,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:40/500,train loss=132.514,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:40/500,train loss=111.632,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:40/500,train loss=129.827,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:41/500,train loss=132.459,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:41/500,train loss=111.572,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:41/500,train loss=129.761,mean train PER=0.798
#
#
# phn mode, total:100,batch:1/3,epoch:42/500,train loss=132.404,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:42/500,train loss=111.515,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:42/500,train loss=129.690,mean train PER=0.798
#
#
# phn mode, total:100,batch:1/3,epoch:43/500,train loss=132.346,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:43/500,train loss=111.457,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:43/500,train loss=129.619,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:44/500,train loss=132.287,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:44/500,train loss=111.396,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:44/500,train loss=129.547,mean train PER=0.798
#
#
# phn mode, total:100,batch:1/3,epoch:45/500,train loss=132.227,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:45/500,train loss=111.331,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:45/500,train loss=129.476,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:46/500,train loss=132.165,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:46/500,train loss=111.264,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:46/500,train loss=129.402,mean train PER=0.798
#
#
# phn mode, total:100,batch:1/3,epoch:47/500,train loss=132.100,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:47/500,train loss=111.196,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:47/500,train loss=129.323,mean train PER=0.799
#
#
# phn mode, total:100,batch:1/3,epoch:48/500,train loss=132.032,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:48/500,train loss=111.126,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:48/500,train loss=129.241,mean train PER=0.799
#
#
# phn mode, total:100,batch:1/3,epoch:49/500,train loss=131.961,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:49/500,train loss=111.053,mean train PER=0.791
#
#
# phn mode, total:100,batch:3/3,epoch:49/500,train loss=129.155,mean train PER=0.799
#
#
# phn mode, total:100,batch:1/3,epoch:50/500,train loss=131.886,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:50/500,train loss=110.975,mean train PER=0.789
#
#
# phn mode, total:100,batch:3/3,epoch:50/500,train loss=129.067,mean train PER=0.799
#
#
# phn mode, total:100,batch:1/3,epoch:51/500,train loss=131.806,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:51/500,train loss=110.892,mean train PER=0.789
#
#
# phn mode, total:100,batch:3/3,epoch:51/500,train loss=128.973,mean train PER=0.798
#
#
# phn mode, total:100,batch:1/3,epoch:52/500,train loss=131.721,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:52/500,train loss=110.805,mean train PER=0.789
#
#
# phn mode, total:100,batch:3/3,epoch:52/500,train loss=128.873,mean train PER=0.799
#
#
# phn mode, total:100,batch:1/3,epoch:53/500,train loss=131.631,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:53/500,train loss=110.713,mean train PER=0.789
#
#
# phn mode, total:100,batch:3/3,epoch:53/500,train loss=128.766,mean train PER=0.799
#
#
# phn mode, total:100,batch:1/3,epoch:54/500,train loss=131.534,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:54/500,train loss=110.616,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:54/500,train loss=128.653,mean train PER=0.800
#
#
# phn mode, total:100,batch:1/3,epoch:55/500,train loss=131.431,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:55/500,train loss=110.513,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:55/500,train loss=128.533,mean train PER=0.800
#
#
# phn mode, total:100,batch:1/3,epoch:56/500,train loss=131.323,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:56/500,train loss=110.403,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:56/500,train loss=128.406,mean train PER=0.800
#
#
# phn mode, total:100,batch:1/3,epoch:57/500,train loss=131.208,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:57/500,train loss=110.288,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:57/500,train loss=128.271,mean train PER=0.800
#
#
# phn mode, total:100,batch:1/3,epoch:58/500,train loss=131.088,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:58/500,train loss=110.168,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:58/500,train loss=128.131,mean train PER=0.801
#
#
# phn mode, total:100,batch:1/3,epoch:59/500,train loss=130.963,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:59/500,train loss=110.044,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:59/500,train loss=127.985,mean train PER=0.801
#
#
# phn mode, total:100,batch:1/3,epoch:60/500,train loss=130.832,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:60/500,train loss=109.915,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:60/500,train loss=127.834,mean train PER=0.802
#
#
# phn mode, total:100,batch:1/3,epoch:61/500,train loss=130.697,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:61/500,train loss=109.783,mean train PER=0.789
#
#
# phn mode, total:100,batch:3/3,epoch:61/500,train loss=127.676,mean train PER=0.802
#
#
# phn mode, total:100,batch:1/3,epoch:62/500,train loss=130.557,mean train PER=0.798
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:62/500,train loss=109.646,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:62/500,train loss=127.512,mean train PER=0.801
#
#
# phn mode, total:100,batch:1/3,epoch:63/500,train loss=130.413,mean train PER=0.797
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:63/500,train loss=109.503,mean train PER=0.788
#
#
# phn mode, total:100,batch:3/3,epoch:63/500,train loss=127.338,mean train PER=0.801
#
#
# phn mode, total:100,batch:1/3,epoch:64/500,train loss=130.268,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:64/500,train loss=109.357,mean train PER=0.787
#
#
# phn mode, total:100,batch:3/3,epoch:64/500,train loss=127.156,mean train PER=0.800
#
#
# phn mode, total:100,batch:1/3,epoch:65/500,train loss=130.116,mean train PER=0.795
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:65/500,train loss=109.206,mean train PER=0.787
#
#
# phn mode, total:100,batch:3/3,epoch:65/500,train loss=126.973,mean train PER=0.800
#
#
# phn mode, total:100,batch:1/3,epoch:66/500,train loss=129.957,mean train PER=0.796
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:66/500,train loss=109.045,mean train PER=0.786
#
#
# phn mode, total:100,batch:3/3,epoch:66/500,train loss=126.786,mean train PER=0.800
#
#
# phn mode, total:100,batch:1/3,epoch:67/500,train loss=129.787,mean train PER=0.795
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:67/500,train loss=108.885,mean train PER=0.784
#
#
# phn mode, total:100,batch:3/3,epoch:67/500,train loss=126.591,mean train PER=0.800
#
#
# phn mode, total:100,batch:1/3,epoch:68/500,train loss=129.606,mean train PER=0.794
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:68/500,train loss=108.720,mean train PER=0.784
#
#
# phn mode, total:100,batch:3/3,epoch:68/500,train loss=126.392,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:69/500,train loss=129.417,mean train PER=0.792
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:69/500,train loss=108.542,mean train PER=0.784
#
#
# phn mode, total:100,batch:3/3,epoch:69/500,train loss=126.190,mean train PER=0.798
#
#
# phn mode, total:100,batch:1/3,epoch:70/500,train loss=129.218,mean train PER=0.792
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:70/500,train loss=108.356,mean train PER=0.784
#
#
# phn mode, total:100,batch:3/3,epoch:70/500,train loss=125.980,mean train PER=0.800
#
#
# phn mode, total:100,batch:1/3,epoch:71/500,train loss=129.014,mean train PER=0.792
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:71/500,train loss=108.161,mean train PER=0.785
#
#
# phn mode, total:100,batch:3/3,epoch:71/500,train loss=125.759,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:72/500,train loss=128.807,mean train PER=0.793
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:72/500,train loss=107.958,mean train PER=0.784
#
#
# phn mode, total:100,batch:3/3,epoch:72/500,train loss=125.530,mean train PER=0.797
#
#
# phn mode, total:100,batch:1/3,epoch:73/500,train loss=128.593,mean train PER=0.791
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:73/500,train loss=107.743,mean train PER=0.783
#
#
# phn mode, total:100,batch:3/3,epoch:73/500,train loss=125.297,mean train PER=0.798
#
#
# phn mode, total:100,batch:1/3,epoch:74/500,train loss=128.372,mean train PER=0.791
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:74/500,train loss=107.518,mean train PER=0.781
#
#
# phn mode, total:100,batch:3/3,epoch:74/500,train loss=125.056,mean train PER=0.798
#
#
# phn mode, total:100,batch:1/3,epoch:75/500,train loss=128.141,mean train PER=0.790
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:75/500,train loss=107.289,mean train PER=0.781
#
#
# phn mode, total:100,batch:3/3,epoch:75/500,train loss=124.804,mean train PER=0.796
#
#
# phn mode, total:100,batch:1/3,epoch:76/500,train loss=127.900,mean train PER=0.789
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:76/500,train loss=107.053,mean train PER=0.779
#
#
# phn mode, total:100,batch:3/3,epoch:76/500,train loss=124.542,mean train PER=0.795
#
#
# phn mode, total:100,batch:1/3,epoch:77/500,train loss=127.648,mean train PER=0.788
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:77/500,train loss=106.808,mean train PER=0.778
#
#
# phn mode, total:100,batch:3/3,epoch:77/500,train loss=124.266,mean train PER=0.795
#
#
# phn mode, total:100,batch:1/3,epoch:78/500,train loss=127.384,mean train PER=0.787
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:78/500,train loss=106.550,mean train PER=0.779
#
#
# phn mode, total:100,batch:3/3,epoch:78/500,train loss=123.975,mean train PER=0.794
#
#
# phn mode, total:100,batch:1/3,epoch:79/500,train loss=127.108,mean train PER=0.785
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:79/500,train loss=106.281,mean train PER=0.779
#
#
# phn mode, total:100,batch:3/3,epoch:79/500,train loss=123.661,mean train PER=0.793
#
#
# phn mode, total:100,batch:1/3,epoch:80/500,train loss=126.816,mean train PER=0.784
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:80/500,train loss=105.995,mean train PER=0.779
#
#
# phn mode, total:100,batch:3/3,epoch:80/500,train loss=123.329,mean train PER=0.790
#
#
# phn mode, total:100,batch:1/3,epoch:81/500,train loss=126.508,mean train PER=0.782
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:81/500,train loss=105.692,mean train PER=0.780
#
#
# phn mode, total:100,batch:3/3,epoch:81/500,train loss=122.973,mean train PER=0.789
#
#
# phn mode, total:100,batch:1/3,epoch:82/500,train loss=126.180,mean train PER=0.782
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:82/500,train loss=105.358,mean train PER=0.777
#
#
# phn mode, total:100,batch:3/3,epoch:82/500,train loss=122.596,mean train PER=0.789
#
#
# phn mode, total:100,batch:1/3,epoch:83/500,train loss=125.827,mean train PER=0.781
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:83/500,train loss=105.006,mean train PER=0.777
#
#
# phn mode, total:100,batch:3/3,epoch:83/500,train loss=122.191,mean train PER=0.785
#
#
# phn mode, total:100,batch:1/3,epoch:84/500,train loss=125.441,mean train PER=0.780
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:84/500,train loss=104.627,mean train PER=0.772
#
#
# phn mode, total:100,batch:3/3,epoch:84/500,train loss=121.755,mean train PER=0.782
#
#
# phn mode, total:100,batch:1/3,epoch:85/500,train loss=125.016,mean train PER=0.778
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:85/500,train loss=104.204,mean train PER=0.769
#
#
# phn mode, total:100,batch:3/3,epoch:85/500,train loss=121.288,mean train PER=0.776
#
#
# phn mode, total:100,batch:1/3,epoch:86/500,train loss=124.546,mean train PER=0.775
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:86/500,train loss=103.730,mean train PER=0.765
#
#
# phn mode, total:100,batch:3/3,epoch:86/500,train loss=120.769,mean train PER=0.773
#
#
# phn mode, total:100,batch:1/3,epoch:87/500,train loss=124.029,mean train PER=0.774
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:87/500,train loss=103.207,mean train PER=0.762
#
#
# phn mode, total:100,batch:3/3,epoch:87/500,train loss=120.184,mean train PER=0.770
#
#
# phn mode, total:100,batch:1/3,epoch:88/500,train loss=123.477,mean train PER=0.775
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:88/500,train loss=102.625,mean train PER=0.761
#
#
# phn mode, total:100,batch:3/3,epoch:88/500,train loss=119.537,mean train PER=0.771
#
#
# phn mode, total:100,batch:1/3,epoch:89/500,train loss=122.898,mean train PER=0.772
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:89/500,train loss=101.987,mean train PER=0.761
#
#
# phn mode, total:100,batch:3/3,epoch:89/500,train loss=118.844,mean train PER=0.769
#
#
# phn mode, total:100,batch:1/3,epoch:90/500,train loss=122.285,mean train PER=0.772
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:90/500,train loss=101.352,mean train PER=0.757
#
#
# phn mode, total:100,batch:3/3,epoch:90/500,train loss=118.139,mean train PER=0.766
#
#
# phn mode, total:100,batch:1/3,epoch:91/500,train loss=121.611,mean train PER=0.768
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:91/500,train loss=100.732,mean train PER=0.755
#
#
# phn mode, total:100,batch:3/3,epoch:91/500,train loss=117.307,mean train PER=0.769
#
#
# phn mode, total:100,batch:1/3,epoch:92/500,train loss=120.889,mean train PER=0.769
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:92/500,train loss=99.952,mean train PER=0.755
#
#
# phn mode, total:100,batch:3/3,epoch:92/500,train loss=116.363,mean train PER=0.769
#
#
# phn mode, total:100,batch:1/3,epoch:93/500,train loss=120.127,mean train PER=0.765
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:93/500,train loss=99.107,mean train PER=0.750
#
#
# phn mode, total:100,batch:3/3,epoch:93/500,train loss=115.436,mean train PER=0.767
#
#
# phn mode, total:100,batch:1/3,epoch:94/500,train loss=119.270,mean train PER=0.765
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:94/500,train loss=98.277,mean train PER=0.750
#
#
# phn mode, total:100,batch:3/3,epoch:94/500,train loss=114.450,mean train PER=0.761
#
#
# phn mode, total:100,batch:1/3,epoch:95/500,train loss=118.350,mean train PER=0.761
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:95/500,train loss=97.361,mean train PER=0.752
#
#
# phn mode, total:100,batch:3/3,epoch:95/500,train loss=113.617,mean train PER=0.755
#
#
# phn mode, total:100,batch:1/3,epoch:96/500,train loss=117.298,mean train PER=0.756
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:96/500,train loss=96.546,mean train PER=0.750
#
#
# phn mode, total:100,batch:3/3,epoch:96/500,train loss=112.967,mean train PER=0.771
#
#
# phn mode, total:100,batch:1/3,epoch:97/500,train loss=116.240,mean train PER=0.750
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:97/500,train loss=95.759,mean train PER=0.741
#
#
# phn mode, total:100,batch:3/3,epoch:97/500,train loss=111.593,mean train PER=0.775
#
#
# phn mode, total:100,batch:1/3,epoch:98/500,train loss=115.331,mean train PER=0.762
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:98/500,train loss=95.582,mean train PER=0.723
#
#
# phn mode, total:100,batch:3/3,epoch:98/500,train loss=110.551,mean train PER=0.766
#
#
# phn mode, total:100,batch:1/3,epoch:99/500,train loss=114.755,mean train PER=0.772
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx
#
# phn mode, total:100,batch:2/3,epoch:99/500,train loss=93.658,mean train PER=0.736
#
#
# phn mode, total:100,batch:3/3,epoch:99/500,train loss=110.317,mean train PER=0.722
#
#
# phn mode, total:100,batch:1/3,epoch:100/500,train loss=113.243,mean train PER=0.763
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:100/500,train loss=93.827,mean train PER=0.767
#
#
# phn mode, total:100,batch:3/3,epoch:100/500,train loss=108.287,mean train PER=0.760
#
#
# phn mode, total:100,batch:1/3,epoch:101/500,train loss=111.621,mean train PER=0.742
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:101/500,train loss=92.079,mean train PER=0.740
#
#
# phn mode, total:100,batch:3/3,epoch:101/500,train loss=106.572,mean train PER=0.769
#
#
# phn mode, total:100,batch:1/3,epoch:102/500,train loss=110.472,mean train PER=0.755
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:102/500,train loss=91.438,mean train PER=0.734
#
#
# phn mode, total:100,batch:3/3,epoch:102/500,train loss=104.843,mean train PER=0.738
#
#
# phn mode, total:100,batch:1/3,epoch:103/500,train loss=109.128,mean train PER=0.760
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:103/500,train loss=89.170,mean train PER=0.739
#
#
# phn mode, total:100,batch:3/3,epoch:103/500,train loss=103.534,mean train PER=0.752
#
#
# phn mode, total:100,batch:1/3,epoch:104/500,train loss=106.546,mean train PER=0.751
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy dx dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:104/500,train loss=88.107,mean train PER=0.745
#
#
# phn mode, total:100,batch:3/3,epoch:104/500,train loss=101.129,mean train PER=0.741
#
#
# phn mode, total:100,batch:1/3,epoch:105/500,train loss=105.518,mean train PER=0.728
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh dx dx dx dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:105/500,train loss=87.022,mean train PER=0.758
#
#
# phn mode, total:100,batch:3/3,epoch:105/500,train loss=100.285,mean train PER=0.782
#
#
# phn mode, total:100,batch:1/3,epoch:106/500,train loss=103.609,mean train PER=0.733
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh dx dx dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:106/500,train loss=85.445,mean train PER=0.701
#
#
# phn mode, total:100,batch:3/3,epoch:106/500,train loss=97.691,mean train PER=0.746
#
#
# phn mode, total:100,batch:1/3,epoch:107/500,train loss=101.695,mean train PER=0.776
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:107/500,train loss=83.746,mean train PER=0.721
#
#
# phn mode, total:100,batch:3/3,epoch:107/500,train loss=96.212,mean train PER=0.713
#
#
# phn mode, total:100,batch:1/3,epoch:108/500,train loss=100.254,mean train PER=0.802
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:108/500,train loss=81.674,mean train PER=0.752
#
#
# phn mode, total:100,batch:3/3,epoch:108/500,train loss=94.939,mean train PER=0.695
#
#
# phn mode, total:100,batch:1/3,epoch:109/500,train loss=97.172,mean train PER=0.728
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh dx dx dx dx dx dx dx dx dx dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:109/500,train loss=81.284,mean train PER=0.751
#
#
# phn mode, total:100,batch:3/3,epoch:109/500,train loss=91.506,mean train PER=0.762
#
#
# phn mode, total:100,batch:1/3,epoch:110/500,train loss=95.446,mean train PER=0.732
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh dx dx dx dx dx dx dx dx r iy w dx h#
#
# phn mode, total:100,batch:2/3,epoch:110/500,train loss=78.816,mean train PER=0.720
#
#
# phn mode, total:100,batch:3/3,epoch:110/500,train loss=91.862,mean train PER=0.716
#
#
# phn mode, total:100,batch:1/3,epoch:111/500,train loss=92.022,mean train PER=0.714
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh dx dx dx dx dx dx dx dx dx r iy w dx dx h#
#
# phn mode, total:100,batch:2/3,epoch:111/500,train loss=77.779,mean train PER=0.706
#
#
# phn mode, total:100,batch:3/3,epoch:111/500,train loss=88.162,mean train PER=0.757
#
#
# phn mode, total:100,batch:1/3,epoch:112/500,train loss=89.871,mean train PER=0.759
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh dx dx dx dx dx dx dx r iy dx h#
#
# phn mode, total:100,batch:2/3,epoch:112/500,train loss=75.040,mean train PER=0.713
#
#
# phn mode, total:100,batch:3/3,epoch:112/500,train loss=85.011,mean train PER=0.687
#
#
# phn mode, total:100,batch:1/3,epoch:113/500,train loss=87.470,mean train PER=0.699
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh dx dx dx dx dx dx dx dx g r iy iy w dx h#
#
# phn mode, total:100,batch:2/3,epoch:113/500,train loss=72.750,mean train PER=0.708
#
#
# phn mode, total:100,batch:3/3,epoch:113/500,train loss=82.259,mean train PER=0.687
#
#
# phn mode, total:100,batch:1/3,epoch:114/500,train loss=84.384,mean train PER=0.693
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx dx dx d ae dx dx dx dx g r iy dx ch h#
#
# phn mode, total:100,batch:2/3,epoch:114/500,train loss=70.677,mean train PER=0.729
#
#
# phn mode, total:100,batch:3/3,epoch:114/500,train loss=79.654,mean train PER=0.707
#
#
# phn mode, total:100,batch:1/3,epoch:115/500,train loss=82.020,mean train PER=0.675
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx dx dx d ae dx dx dx dx dx g r iy iy w dx ch h#
#
# phn mode, total:100,batch:2/3,epoch:115/500,train loss=67.990,mean train PER=0.691
#
#
# phn mode, total:100,batch:3/3,epoch:115/500,train loss=77.245,mean train PER=0.705
#
#
# phn mode, total:100,batch:1/3,epoch:116/500,train loss=78.497,mean train PER=0.646
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx dx dx d ae dx dx dx dx g r iy iy w dx ch h#
#
# phn mode, total:100,batch:2/3,epoch:116/500,train loss=66.091,mean train PER=0.639
#
#
# ...
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:468/500,train loss=0.058,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:468/500,train loss=0.065,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:469/500,train loss=0.064,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:469/500,train loss=0.058,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:469/500,train loss=0.064,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:470/500,train loss=0.063,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:470/500,train loss=0.058,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:470/500,train loss=0.064,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:471/500,train loss=0.063,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:471/500,train loss=0.057,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:471/500,train loss=0.064,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:472/500,train loss=0.063,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:472/500,train loss=0.057,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:472/500,train loss=0.064,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:473/500,train loss=0.062,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:473/500,train loss=0.057,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:473/500,train loss=0.063,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:474/500,train loss=0.062,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:474/500,train loss=0.057,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:474/500,train loss=0.063,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:475/500,train loss=0.062,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:475/500,train loss=0.056,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:475/500,train loss=0.063,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:476/500,train loss=0.061,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:476/500,train loss=0.056,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:476/500,train loss=0.062,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:477/500,train loss=0.061,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:477/500,train loss=0.056,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:477/500,train loss=0.062,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:478/500,train loss=0.061,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:478/500,train loss=0.056,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:478/500,train loss=0.062,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:479/500,train loss=0.061,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:479/500,train loss=0.055,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:479/500,train loss=0.061,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:480/500,train loss=0.060,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:480/500,train loss=0.055,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:480/500,train loss=0.061,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:481/500,train loss=0.060,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:481/500,train loss=0.055,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:481/500,train loss=0.061,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:482/500,train loss=0.060,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:482/500,train loss=0.055,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:482/500,train loss=0.061,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:483/500,train loss=0.059,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:483/500,train loss=0.054,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:483/500,train loss=0.060,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:484/500,train loss=0.059,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:484/500,train loss=0.054,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:484/500,train loss=0.060,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:485/500,train loss=0.059,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:485/500,train loss=0.054,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:485/500,train loss=0.060,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:486/500,train loss=0.059,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:486/500,train loss=0.054,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:486/500,train loss=0.059,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:487/500,train loss=0.058,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:487/500,train loss=0.053,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:487/500,train loss=0.059,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:488/500,train loss=0.058,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:488/500,train loss=0.053,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:488/500,train loss=0.059,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:489/500,train loss=0.058,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:489/500,train loss=0.053,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:489/500,train loss=0.059,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:490/500,train loss=0.058,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:490/500,train loss=0.053,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:490/500,train loss=0.058,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:491/500,train loss=0.057,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:491/500,train loss=0.052,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:491/500,train loss=0.058,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:492/500,train loss=0.057,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:492/500,train loss=0.052,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:492/500,train loss=0.058,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:493/500,train loss=0.057,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:493/500,train loss=0.052,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:493/500,train loss=0.058,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:494/500,train loss=0.056,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:494/500,train loss=0.052,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:494/500,train loss=0.057,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:495/500,train loss=0.056,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:495/500,train loss=0.051,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:495/500,train loss=0.057,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:496/500,train loss=0.056,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:496/500,train loss=0.051,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:496/500,train loss=0.057,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:497/500,train loss=0.056,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:497/500,train loss=0.051,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:497/500,train loss=0.057,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:498/500,train loss=0.055,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:498/500,train loss=0.051,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:498/500,train loss=0.056,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:499/500,train loss=0.055,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:499/500,train loss=0.050,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:499/500,train loss=0.056,mean train PER=0.000
#
#
# phn mode, total:100,batch:1/3,epoch:500/500,train loss=0.055,mean train PER=0.000
#
# Truth:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
# Output:
# h# n iy eh ae dx jh y er dx d ae r dx k s jh dx ix ng dx g r iy s iy w ae n dx w ae dx ch dx ae l y el ch h#
#
# phn mode, total:100,batch:2/3,epoch:500/500,train loss=0.050,mean train PER=0.000
#
#
# phn mode, total:100,batch:3/3,epoch:500/500,train loss=0.056,mean train PER=0.000

# %%
phn = ['aa', 'ae', 'ah', 'ao', 'aw', 'ax', 'ax-h',\
   'axr', 'ay', 'b', 'bcl', 'ch', 'd', 'dcl',\
   'dh', 'dx', 'eh', 'el', 'em', 'en', 'eng',\
   'epi', 'er', 'ey', 'f', 'g', 'gcl', 'h#',\
   'hh', 'hv', 'ih', 'ix', 'iy', 'jh', 'k',\
   'kcl', 'l', 'm', 'n', 'ng', 'nx', 'ow',\
   'oy', 'p', 'pau', 'pcl', 'q', 'r', 's',\
   'sh', 't', 'tcl', 'th', 'uh', 'uw', 'ux',\
   'v', 'w', 'y', 'z', 'zh']

mapping = {'ah': 'ax', 'ax-h': 'ax', 'ux': 'uw', 'aa': 'ao', 'ih': 'ix', \
           'axr': 'er', 'el': 'l', 'em': 'm', 'en': 'n', 'nx': 'n',\
           'eng': 'ng', 'sh': 'zh', 'hv': 'hh', 'bcl': 'h#', 'pcl': 'h#',\
           'dcl': 'h#', 'tcl': 'h#', 'gcl': 'h#', 'kcl': 'h#',\
           'q': 'h#', 'epi': 'h#', 'pau': 'h#'}

group_phn = ['ae', 'ao', 'aw', 'ax', 'ay', 'b', 'ch', 'd', 'dh', 'dx', 'eh', \
             'er', 'ey', 'f', 'g', 'h#', 'hh', 'ix', 'iy', 'jh', 'k', 'l', \
             'm', 'n', 'ng', 'ow', 'oy', 'p', 'r', 's', 't', 'th', 'uh', 'uw',\
             'v', 'w', 'y', 'z', 'zh']
print(len(phn))
print(len(mapping))
print(len(group_phn))

mapping = {'ah': 'ax', 'ax-h': 'ax', 'ux': 'uw', 'aa': 'ao', 'ih': 'ix', \
           'axr': 'er', 'el': 'l', 'em': 'm', 'en': 'n', 'nx': 'n',\
           'eng': 'ng', 'sh': 'zh', 'hv': 'hh', 'bcl': 'h#', 'pcl': 'h#',\
           'dcl': 'h#', 'tcl': 'h#', 'gcl': 'h#', 'kcl': 'h#',\
           'q': 'h#', 'epi': 'h#', 'pau': 'h#'}

group_phn = ['ae', 'ao', 'aw', 'ax', 'ay', 'b', 'ch', 'd', 'dh', 'dx', 'eh', \
             'er', 'ey', 'f', 'g', 'h#', 'hh', 'ix', 'iy', 'jh', 'k', 'l', \
             'm', 'n', 'ng', 'ow', 'oy', 'p', 'r', 's', 't', 'th', 'uh', 'uw',\
             'v', 'w', 'y', 'z', 'zh']

print(len(mapping))
print(len(group_phn))
# Out:
# 61
# 22
# 39
# 22
# 39
